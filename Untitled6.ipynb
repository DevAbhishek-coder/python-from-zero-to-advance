# %%
#STRINGS BUILT IN FUNCTION
#STRINGS ARE ALWAYS WRITTEN UNDER SINGLE OR DOUBLE QUOTES

name = "Abhishek Singh Raghuvansi"
print(name)
# Out:
# Abhishek Singh Raghuvansi

# %%
type(name)
# Out:
# str

# %%
len(name)
# Out:
# 25

# %%
#FIND FUNCTION Return the lowest index in S where substring sub is found.

name.find("i")
# Out:
# 3

# %%
#FIND FUNCTION Return the lowest index in S where substring sub is found.
str2 = "APPLE"
str2.find("P")
# Out:
# 1

# %%
#in case any data is not available in the during search. it will return -1
name.find("z")
# Out:
# -1

# %%
#COUNT IT RETURN THE TOTAL NUMBER OF DATA APPEARING
str2.count('P')
# Out:
# 2

# %%
#UPPER CONVERT ALL LETTERS INTO UPPER CASE

s1 = "abhishek singh"
s1.upper()
# Out:
# 'ABHISHEK SINGH'

# %%
#LOWER CONVERT ALL LETTERS INTO LOWER CASE 
s2 = "ABHiSHeK"
s2.lower()
# Out:
# 'abhishek'

# %%
#SWAPCASE:- IT SWAP CAPITAL INTO SMALL AND SMALL INTO CAPITAL
s2.swapcase()
# Out:
# 'abhIshEk'
